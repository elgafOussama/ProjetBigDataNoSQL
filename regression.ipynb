# %%
import pandas as pd
dataset = pd.read_csv("dataset.csv")
dataset.head()
# Out:
#    TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0       0         Cash loans           F            N               Y
# 1       0         Cash loans           M            Y               N
# 2       0         Cash loans           F            N               Y
# 3       0         Cash loans           M            Y               N
# 4       0         Cash loans           F            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          256500.0   1008117.0      29475.0         841500.0
# 1             0          202500.0   1575000.0      43312.5        1575000.0
# 2             0          202500.0    610335.0      20299.5         463500.0
# 3             0          337500.0   1125000.0      32895.0        1125000.0
# 4             0          112500.0    862560.0      25218.0         720000.0
#
#                ...              FLOORSMAX_AVG FLOORSMIN_AVG LANDAREA_AVG  \
# ...

# %%
dataset.columns
# Out:
# Index(['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL',
#        'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
#        'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
# ...

# %%
dataset.columns.size
# Out:
# 60

# %%
len(dataset.index)
# Out:
# 300000

# %%
dataset["TARGET"].dtype
# Out:
# dtype('int64')

# %%
import matplotlib.pyplot as plt
dataset[dataset.TARGET==1].mean().sort_values().plot(kind="barh", figsize=(15,15))

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 60 columns):
# TARGET                          300000 non-null int64
# NAME_CONTRACT_TYPE              300000 non-null object
# CODE_GENDER                     300000 non-null object
# FLAG_OWN_CAR                    300000 non-null object
# FLAG_OWN_REALTY                 300000 non-null object
# CNT_CHILDREN                    300000 non-null int64
# AMT_INCOME_TOTAL                300000 non-null float64
# AMT_CREDIT                      300000 non-null float64
# AMT_ANNUITY                     299990 non-null float64
# AMT_GOODS_PRICE                 299728 non-null float64
# NAME_TYPE_SUITE                 298739 non-null object
# NAME_INCOME_TYPE                300000 non-null object
# NAME_EDUCATION_TYPE             300000 non-null object
# NAME_FAMILY_STATUS              300000 non-null object
# NAME_HOUSING_TYPE               300000 non-null object
# ...

# %%
dataset.dtypes
# Out:
# TARGET                            int64
# NAME_CONTRACT_TYPE               object
# CODE_GENDER                      object
# FLAG_OWN_CAR                     object
# FLAG_OWN_REALTY                  object
# CNT_CHILDREN                      int64
# AMT_INCOME_TOTAL                float64
# AMT_CREDIT                      float64
# AMT_ANNUITY                     float64
# AMT_GOODS_PRICE                 float64
# NAME_TYPE_SUITE                  object
# NAME_INCOME_TYPE                 object
# NAME_EDUCATION_TYPE              object
# NAME_FAMILY_STATUS               object
# NAME_HOUSING_TYPE                object
# REGION_POPULATION_RELATIVE      float64
# DAYS_BIRTH                        int64
# DAYS_EMPLOYED                     int64
# DAYS_REGISTRATION               float64
# DAYS_ID_PUBLISH                   int64
# OWN_CAR_AGE                     float64
# FLAG_MOBIL                        int64
# FLAG_EMP_PHONE                    int64
# ...

# %%
dataset[dataset.TARGET==1].describe(include='all')
# Out:
#          TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# count   24191.0              24191       24191        24191           24191
# unique      NaN                  2           2            2               2
# top         NaN         Cash loans           F            N               Y
# freq        NaN              22614       13811        16794           16546
# mean        1.0                NaN         NaN          NaN             NaN
# std         0.0                NaN         NaN          NaN             NaN
# min         1.0                NaN         NaN          NaN             NaN
# 25%         1.0                NaN         NaN          NaN             NaN
# 50%         1.0                NaN         NaN          NaN             NaN
# 75%         1.0                NaN         NaN          NaN             NaN
# max         1.0                NaN         NaN          NaN             NaN
#
# ...

# %%
dataset[dataset.TARGET==0].describe(include='all')
# Out:
#           TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# count   275809.0             275809      275809       275809          275809
# unique       NaN                  2           3            2               2
# top          NaN         Cash loans           F            N               Y
# freq         NaN             248860      183687       181125          191517
# mean         0.0                NaN         NaN          NaN             NaN
# std          0.0                NaN         NaN          NaN             NaN
# min          0.0                NaN         NaN          NaN             NaN
# 25%          0.0                NaN         NaN          NaN             NaN
# 50%          0.0                NaN         NaN          NaN             NaN
# 75%          0.0                NaN         NaN          NaN             NaN
# max          0.0                NaN         NaN          NaN             NaN
#
# ...

# %%
pretOK = dataset.TARGET.value_counts()
print((pretOK[1]/pretOK.sum())*100)
print((pretOK[0]/pretOK.sum())*100)
# Out:
# 8.063666666666666
# 91.93633333333334

# %%
from sklearn.preprocessing import LabelEncoder as lblencoder

dataset.CODE_GENDER = lblencoder.fit_transform(dataset.CODE_GENDER)
dataset[dataset.TARGET==1].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1b8f7d2d4007> in <module>
#       1 from sklearn.preprocessing import LabelEncoder as lblencoder
#       2
# ----> 3 dataset.CODE_GENDER = lblencoder.fit_transform(dataset.CODE_GENDER)
#       4 dataset[dataset.TARGET==1].mean()
#
# TypeError: fit_transform() missing 1 required positional argument: 'y'

# %%
dataset[dataset.TARGET==0].mean()
